# %%
# imports and setup
# %matplotlib inline

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from itertools import chain, combinations
import statsmodels.api as sm

pd.set_option('precision',4)
pd.set_option('display.max_rows',12)
pd.set_option('display.max_columns',12)
pd.set_option('display.float_format','{:20,.5f}'.format)

plt.style.use('seaborn')

# %%
weatherHistory = pd.read_csv('datasets/weatherHistory.csv')
weatherHistory = weatherHistory.dropna()
weatherHistory = weatherHistory.drop_duplicates()
weatherHistory
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#            Temperature (C)  Apparent Temperature (C)             Humidity  \
# 0                  9.47222                   7.38889              0.89000
# 1                  9.35556                   7.22778              0.86000
# 2                  9.37778                   9.37778              0.89000
# 3                  8.28889                   5.94444              0.83000
# 4                  8.75556                   6.97778              0.83000
# ...                    ...                       ...                  ...
# 96448             26.01667                  26.01667              0.43000
# 96449             24.58333                  24.58333              0.48000
# 96450             22.03889                  22.03889              0.56000
# 96451             21.52222                  21.52222              0.60000
# 96452             20.43889                  20.43889              0.61000
#
#          Wind Speed (km/h)  Wind Bearing (degrees)      Visibility (km)  \
# 0                 14.11970               251.00000             15.82630
# 1                 14.26460               259.00000             15.82630
# 2                  3.92840               204.00000             14.95690
# 3                 14.10360               269.00000             15.82630
# 4                 11.04460               259.00000             15.82630
# ...                    ...                     ...                  ...
# 96448             10.99630                31.00000             16.10000
# 96449             10.09470                20.00000             15.55260
# 96450              8.98380                30.00000             16.10000
# 96451             10.52940                20.00000             16.10000
# 96452              5.87650                39.00000             15.52040
#
#                 Loud Cover  Pressure (millibars)  \
# 0                  0.00000           1,015.13000
# 1                  0.00000           1,015.63000
# 2                  0.00000           1,015.94000
# 3                  0.00000           1,016.41000
# 4                  0.00000           1,016.51000
# ...                    ...                   ...
# 96448              0.00000           1,014.36000
# 96449              0.00000           1,015.16000
# 96450              0.00000           1,015.66000
# 96451              0.00000           1,015.95000
# 96452              0.00000           1,016.16000
#
#                                 Daily Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.
#
# [95912 rows x 12 columns]

# %%
weatherHistory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95912 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95912 non-null  object
#  1   Summary                   95912 non-null  object
#  2   Precip Type               95912 non-null  object
#  3   Temperature (C)           95912 non-null  float64
#  4   Apparent Temperature (C)  95912 non-null  float64
#  5   Humidity                  95912 non-null  float64
#  6   Wind Speed (km/h)         95912 non-null  float64
#  7   Wind Bearing (degrees)    95912 non-null  float64
#  8   Visibility (km)           95912 non-null  float64
#  9   Loud Cover                95912 non-null  float64
#  10  Pressure (millibars)      95912 non-null  float64
#  11  Daily Summary             95912 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 9.5+ MB

# %%
weatherHistory.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
weatherHistory.shape
# Out:
# (95912, 12)

# %%
weatherHistory.describe()
# Out:
#            Temperature (C)  Apparent Temperature (C)             Humidity  \
# count         95,912.00000              95,912.00000         95,912.00000
# mean              11.93797                  10.85919              0.73484
# std                9.56962                  10.71671              0.19572
# min              -21.82222                 -27.71667              0.00000
# 25%                4.59444                   2.27222              0.60000
# 50%               12.02222                  12.02222              0.78000
# 75%               18.84444                  18.84444              0.89000
# max               39.90556                  39.34444              1.00000
#
#          Wind Speed (km/h)  Wind Bearing (degrees)      Visibility (km)  \
# count         95,912.00000            95,912.00000         95,912.00000
# mean              10.80676               187.50699             10.36231
# std                6.92050               107.37831              4.17420
# min                0.00000                 0.00000              0.00000
# 25%                5.81210               116.00000              8.35590
# 50%                9.93370               180.00000             10.04640
# 75%               14.13580               290.00000             14.81200
# max               63.85260               359.00000             16.10000
#
#                 Loud Cover  Pressure (millibars)
# count         95,912.00000          95,912.00000
# mean               0.00000           1,003.14696
# std                0.00000             117.29148
# min                0.00000               0.00000
# 25%                0.00000           1,011.89000
# 50%                0.00000           1,016.42000
# 75%                0.00000           1,021.05000
# max                0.00000           1,046.38000

# %%
weatherHistory.hist(bins=50, figsize=(20,15))
plt.show()

# %%
weatherHistory.corr()
# Out:
#                               Temperature (C)  Apparent Temperature (C)  \
# Temperature (C)                       1.00000                   0.99263
# Apparent Temperature (C)              0.99263                   1.00000
# Humidity                             -0.63222                  -0.60246
# Wind Speed (km/h)                     0.00866                  -0.05706
# Wind Bearing (degrees)                0.02984                   0.02885
# Visibility (km)                       0.39381                   0.38268
# Loud Cover                                NaN                       NaN
# Pressure (millibars)                 -0.00529                  -0.00007
#
#                                      Humidity    Wind Speed (km/h)  \
# Temperature (C)                      -0.63222              0.00866
# Apparent Temperature (C)             -0.60246             -0.05706
# Humidity                              1.00000             -0.22470
# Wind Speed (km/h)                    -0.22470              1.00000
# Wind Bearing (degrees)                0.00077              0.10448
# Visibility (km)                      -0.37062              0.10085
# Loud Cover                                NaN                  NaN
# Pressure (millibars)                  0.00538             -0.04943
#
#                           Wind Bearing (degrees)      Visibility (km)  \
# Temperature (C)                          0.02984              0.39381
# Apparent Temperature (C)                 0.02885              0.38268
# Humidity                                 0.00077             -0.37062
# Wind Speed (km/h)                        0.10448              0.10085
# Wind Bearing (degrees)                   1.00000              0.04889
# Visibility (km)                          0.04889              1.00000
# Loud Cover                                   NaN                  NaN
# Pressure (millibars)                    -0.01164              0.06101
#
#                           Loud Cover  Pressure (millibars)
# Temperature (C)                  NaN              -0.00529
# Apparent Temperature (C)         NaN              -0.00007
# Humidity                         NaN               0.00538
# Wind Speed (km/h)                NaN              -0.04943
# Wind Bearing (degrees)           NaN              -0.01164
# Visibility (km)                  NaN               0.06101
# Loud Cover                       NaN                   NaN
# Pressure (millibars)             NaN               1.00000

# %%
sns.scatterplot(x='Humidity',y='Apparent Temperature (C)',hue='Temperature (C)',data=weatherHistory,marker="+",color="g");

# %%
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

lm = LinearRegression(fit_intercept=True)

X, y = weatherHistory.loc[:,['Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
       'Pressure (millibars)']],weatherHistory['Apparent Temperature (C)']

def processSubset(feature_set):
    model = sm.OLS(y,X[list(feature_set)])
    regr = model.fit()
    RSS = regr.ssr
    RSS = regr.ssr
    return {'model':regr,'RSS':RSS}

def forward(predictors):
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    results =[]
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    models = pd.DataFrame(results)
    best_model = models.loc[models['RSS'].argmin()]
    return best_model

models2 = pd.DataFrame(columns=['RSS','model'])

predictors = []

for i in range(1,len(X.columns)+1):
    models2.loc[i] = forward(predictors)
    predictors = models2.loc[i]['model'].model.exog_names

bic_f = []

for m in models2.model:
    bic_f.append(m.bic)
np.array(bic_f).argmin()
# Out:
# 5

# %%
predictors, bic_f
# Out:
# (['Temperature (C)',
#   'Wind Speed (km/h)',
#   'Pressure (millibars)',
#   'Visibility (km)',
#   'Wind Bearing (degrees)',
#   'Humidity',
#   'Loud Cover'],
#  [404201.95930864185,
#   313734.77435122116,
#   291163.1002223875,
#   290989.66487493354,
#   290890.09078770556,
#   290879.79248409014,
#   290879.79248409014])

# %%
X, y = weatherHistory.loc[:,['Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
       'Pressure (millibars)']],weatherHistory['Apparent Temperature (C)']

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.9,test_size=0.1,random_state=42)

lm_fit = lm.fit(X_train,y_train)

lm_predict = lm_fit.predict(X_test)

print(pd.Series(lm_fit.coef_, index=X.columns))
print('MSE: ',mean_squared_error(y_test,lm_predict))
# Out:
# Temperature (C)                       1.12560
# Humidity                              1.04945
# Wind Speed (km/h)                    -0.09599
# Wind Bearing (degrees)                0.00052
# Visibility (km)                      -0.00080
# Loud Cover                            0.00000
# Pressure (millibars)                  0.00019
# dtype: float64
# MSE:  1.187290047885709

# %%
sns.regplot(x=lm_predict,y=y_test);
